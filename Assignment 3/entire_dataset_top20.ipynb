# %%
import json
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
f = open('aljazeera.json')
aljazeera = json.load(f)
al_person = aljazeera['PERSON']
al_norp = aljazeera['NORP']
al_org = aljazeera['ORG']
al_gpe = aljazeera['GPE']
al_loc = aljazeera['LOC']

# %%
f = open('cnn.json')
cnn = json.load(f)
cnn_person = cnn['PERSON']
cnn_norp = cnn['NORP']
cnn_org = cnn['ORG']
cnn_gpe = cnn['GPE']
cnn_loc = cnn['LOC']

# %%
f = open('fox.json')
fox = json.load(f)
fox_person = fox['PERSON']
fox_norp = fox['NORP']
fox_org = fox['ORG']
fox_gpe = fox['GPE']
fox_loc = fox['LOC']

# %%
person = al_person + cnn_person + fox_person
person_df = pd.DataFrame()
person_df['PERSON'] = person

person_count = person_df['PERSON'].value_counts().reset_index()
person_count.columns = ['PERSON', 'Count']
person_top20 = person_count.iloc[0:20]
person_top20
# Out:
#                  PERSON  Count
# 0                 Putin   1164
# 1                 Biden    811
# 2              Zelensky    419
# 3        Vladimir Putin    415
# 4             Joe Biden    317
# 5    Volodymyr Zelensky    221
# 6   Volodymyr Zelenskyy    219
# 7          Zaporizhzhia    186
# 8             Zelenskyy    173
# 9               Kherson    146
# 10          Greg Norman    127
# 11                Kirby    125
# 12     Lawrence Richard    115
# 13          Michael Lee    108
# 14                 Kyiv    101
# 15              Blinken     98
# 16       Antony Blinken     97
# 17              Kharkiv     86
# 18           John Kirby     81
# 19        Boris Johnson     70

# %%
ax = sns.barplot(x = 'PERSON', y = 'Count', data = person_top20, color = 'red')
ax.set_title('Entire Dataset: Top 20 Mentioned PERSON', fontsize = 15)
ax.bar_label(ax.containers[0])

sns.set(rc = {'figure.figsize':(10,5)})
plt.xticks(rotation = 90, horizontalalignment = "center")
plt.show()

# %%
norp = al_norp + cnn_norp + fox_norp
norp_df = pd.DataFrame()
norp_df['NORP'] = norp

norp_count = norp_df['NORP'].value_counts().reset_index()
norp_count.columns = ['NORP', 'Count']
norp_top20 = norp_count.iloc[0:20]
norp_top20
# Out:
#           NORP  Count
# 0      Russian   6385
# 1    Ukrainian   2094
# 2   Ukrainians    528
# 3     Russians    409
# 4     European    243
# 5       Polish    212
# 6       French    203
# 7     American    199
# 8      Chinese    142
# 9       German    129
# 10     British    126
# 11     Turkish    103
# 12     Western    102
# 13  Belarusian     78
# 14     Israeli     55
# 15   Americans     51
# 16      Soviet     47
# 17  Republican     39
# 18       Czech     37
# 19     Chechen     35

# %%
ax = sns.barplot(x = 'NORP', y = 'Count', data = norp_top20, color = 'orange')
ax.set_title('Entire Dataset: Top 20 Mentioned NORP', fontsize = 15)
ax.bar_label(ax.containers[0])

sns.set(rc = {'figure.figsize':(10,5)})
plt.xticks(rotation = 90, horizontalalignment = "center")
plt.show()

# %%
org = al_org + cnn_org + fox_org
org_df = pd.DataFrame()
org_df['ORG'] = org

org_count = org_df['ORG'].value_counts().reset_index()
org_count.columns = ['ORG', 'Count']
org_top20 = org_count.iloc[0:20]
org_top20
# Out:
#                 ORG  Count
# 0               CNN   1754
# 1               GMT   1501
# 2              NATO   1154
# 3          Mariupol   1049
# 4                UN    521
# 5                EU    393
# 6           Kremlin    339
# 7          Fox News    320
# 8              2022    254
# 9          Pentagon    221
# 10            Biden    215
# 11          Reuters    215
# 12       Al Jazeera    197
# 13      White House    192
# 14             IAEA    179
# 15               ET    179
# 16  the White House    154
# 17            State    151
# 18         Telegram    148
# 19         Congress    127

# %%
ax = sns.barplot(x = 'ORG', y = 'Count', data = org_top20, color = 'yellow')
ax.set_title('Entire Dataset: Top 20 Mentioned ORG', fontsize = 15)
ax.bar_label(ax.containers[0])

sns.set(rc = {'figure.figsize':(10,5)})
plt.xticks(rotation = 90, horizontalalignment = "center")
plt.show()

# %%
gpe = al_gpe + cnn_gpe + fox_gpe
gpe_df = pd.DataFrame()
gpe_df['GPE'] = gpe

gpe_count = gpe_df['GPE'].value_counts().reset_index()
gpe_count.columns = ['GPE', 'Count']
gpe_top20 = gpe_count.iloc[0:20]
gpe_top20
# Out:
#                   GPE  Count
# 0             Ukraine   8360
# 1              Russia   6410
# 2                  US   2278
# 3              Moscow    995
# 4           Ukrainian    717
# 5              Poland    653
# 6               China    521
# 7                  UK    289
# 8                U.S.    249
# 9             Germany    244
# 10           Mariupol    230
# 11  the United States    226
# 12               Lviv    218
# 13            Belarus    208
# 14             Turkey    199
# 15          Chernobyl    196
# 16               Kyiv    186
# 17           Brussels    185
# 18             France    150
# 19             Warsaw    124

# %%
ax = sns.barplot(x = 'GPE', y = 'Count', data = gpe_top20, color = 'green')
ax.set_title('Entire Dataset: Top 20 Mentioned GPE', fontsize = 15)
ax.bar_label(ax.containers[0])

sns.set(rc = {'figure.figsize':(10,5)})
plt.xticks(rotation = 90, horizontalalignment = "center")
plt.show()

# %%
loc = al_loc + cnn_loc + fox_loc
loc_df = pd.DataFrame()
loc_df['LOC'] = loc

loc_count = loc_df['LOC'].value_counts().reset_index()
loc_count.columns = ['LOC', 'Count']
loc_top20 = loc_count.iloc[0:20]
loc_top20
# Out:
#                   LOC  Count
# 0              Europe    493
# 1                West    115
# 2           Black Sea     47
# 3       the Black Sea     46
# 4           Zelenskyy     24
# 5              Africa     15
# 6     the Sea of Azov     14
# 7     the Middle East     13
# 8      Eastern Europe     12
# 9                Asia     12
# 10        Middle East      9
# 11       the Azov Sea      8
# 12               Gulf      8
# 13  the Dnieper River      8
# 14               East      7
# 15    the Irpin River      7
# 16            Kharkiv      6
# 17             Allies      6
# 18               Mars      6
# 19          Peninsula      4

# %%
ax = sns.barplot(x = 'LOC', y = 'Count', data = loc_top20, color = 'blue')
ax.set_title('Entire Dataset: Top 20 Mentioned LOC', fontsize = 15)
ax.bar_label(ax.containers[0])

sns.set(rc = {'figure.figsize':(10,5)})
plt.xticks(rotation = 90, horizontalalignment = "center")
plt.show()
